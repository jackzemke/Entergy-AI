# %%
import pandas as pd
import openai
import os
import time
import re
import glob



# try to use batch call with openai

# %%
def is_substantive_safe(text):
    """Check if the text has substantive content, handling missing or non-string values safely."""
    if not isinstance(text, str):
        return False
    
    # Define keywords and minimum length to consider the content substantive
    min_length = 10
    financial_terms = [
        "earnings", "revenue", "forecast", "guidance", "expense", "growth", "margin", 
        "profit", "quarter", "operating", "investment", "cash flow", "assets", "liabilities",
        "dividend", "debt", "capital", "equity", "net income", "costs", "shareholder", 
        "acquisition", "merger", "balance sheet", "market conditions", "supply chain", 
        "inflation", "interest rate", "valuation", "EBITDA", "tax", "cost reduction", 
        "production", "sales", "pricing", "strategy", "projections", "financial performance"
    ]
    
    # Check if the text length is above a threshold or contains financial terms
    if len(text.split()) > min_length or any(term in text.lower() for term in financial_terms):
        return True
    
    # Check if there are sentences beyond initial greetings
    greeting_pattern = r"^(hi|hello|good morning|good afternoon|thank you|thanks),?\s*"
    cleaned_text = re.sub(greeting_pattern, "", text.lower()).strip()
    if len(cleaned_text.split()) > min_length or any(term in cleaned_text for term in financial_terms):
        return True
    
    return False

def clean_qa_dataframe_safe(df):
    """Clean the dataframe by removing rows with non-substantive questions and answers, handling edge cases."""
    # Filter rows where both Question and Answer have substantive content
    df_cleaned = df[df['Question'].apply(is_substantive_safe) & df['Answer'].apply(is_substantive_safe)]
    return df_cleaned

def clean_all_csvs_in_directory(directory_path):
    """Clean all CSV files in the specified directory."""
    csv_files = glob.glob(os.path.join(directory_path, "*.csv"))
    
    for file_path in csv_files:
        try:
            df = pd.read_csv(file_path)
            cleaned_df = clean_qa_dataframe_safe(df)
            cleaned_filename = os.path.join('/Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs', f"cleaned_{os.path.basename(file_path)}")
            cleaned_df.to_csv(cleaned_filename, index=False)
            print(f"Cleaned file saved to {cleaned_filename}")
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

# Example usage
directory_path = "/Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/earningsQAs"  
clean_all_csvs_in_directory(directory_path)
# Out:
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2015-2-05.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2014-2-11.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2022-11-02.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2020-10-28.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2018-8-01.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2024-2-22.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2016-10-25.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2023-4-26.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2022-4-27.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2013-10-29.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2016-4-26.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2017-4-26.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2019-7-31.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2021-8-04.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2023-11-01.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2022-2-23.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2013-7-30.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2024-4-24.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2015-8-04.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2015-4-28.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2017-10-24.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2021-4-28.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2016-2-18.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2017-2-15.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2019-5-01.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2019-2-20.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2023-2-16.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2013-2-08.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2014-4-24.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2018-2-23.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2015-11-02.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2024-8-01.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2019-10-30.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2014-7-29.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2017-8-02.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2016-8-02.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2023-8-02.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2021-2-24.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2020-5-11.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2012-11-05.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2021-11-03.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2020-7-29.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2020-2-19.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2022-8-03.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2018-4-25.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2014-11-04.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2013-4-25.csv
# Cleaned file saved to /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/clean_QAs/cleaned_earnings_qa_2018-10-31.csv

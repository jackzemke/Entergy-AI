# %%
from sec_edgar_downloader import Downloader
import os

# Initialize Downloader
dl = Downloader("/Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/SO-10QHTML", 
                email_address="peter.sapountzis@gmail.com")

# Download 10-Q filings
print("Starting download...")
try:
    dl.get("10-Q", "788784")  # Adjust amount as needed
    print("Download complete!")
except Exception as e:
    print(f"Error during download: {e}")

# Verify the downloaded files
for root, dirs, files in os.walk("/Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/SO-10QHTML"):
    for name in files:
        print(f"Downloaded file: {os.path.join(root, name)}")
# Out:
# Starting download...
# Download complete!

# %%
import os
import re
import json
import uuid

# Input and output directories
input_dir = "/Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q"  # Change to your directory
output_dir = "/Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/data/pseg_10q_json"  # Change to your output directory
os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists

KEY_INDICATORS = [
    "Operating revenues", "Net income", "Total assets", 
    "Total liabilities", "Cash and cash equivalents", 
    "Depreciation and amortization", "Interest expense"
]

def extract_date(content):
    """Extract the report date from the content."""
    match = re.search(r"For the (quarter|year) ended (\w+ \d{1,2}, \d{4})", content, re.IGNORECASE)
    if match:
        return match.group(2).replace(" ", "-")
    return f"unknown_{uuid.uuid4()}"

def extract_table_data(content):
    """Extract financial data from text tables."""
    financial_data = {}
    for indicator in KEY_INDICATORS:
        pattern = rf"{indicator}.*?([\d\(\),\-\.]+).*?([\d\(\),\-\.]+).*?([\d\(\),\-\.]+)"
        match = re.search(pattern, content, re.IGNORECASE | re.DOTALL)
        if match:
            values = [convert_to_number(value) for value in match.groups()]
            financial_data[indicator] = {
                "Utility": values[0],
                "Parent & Other": values[1],
                "Total": values[2]
            }
    return financial_data

def convert_to_number(value):
    """Convert a string value to a number or None."""
    value = value.replace(",", "").replace("(", "-").replace(")", "").strip()
    if value in {"", "-", "—"}:
        return None
    try:
        return float(value)
    except ValueError:
        return value

def parse_txt_file(file_path):
    """Parse a single 10-Q text file and extract data."""
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()

    report_date = extract_date(content)
    financial_data = extract_table_data(content)
    financial_data["Report Date"] = report_date

    return financial_data

def save_to_json(data, filename):
    """Save extracted data to a JSON file."""
    output_path = os.path.join(output_dir, filename)
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)

def main():
    """Main function to iterate through text files and extract financial data."""
    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                print(f"Parsing {file_path}...")

                financial_data = parse_txt_file(file_path)
                json_filename = f"{financial_data['Report Date']}.json"

                save_to_json(financial_data, json_filename)
                print(f"Saved parsed data to {json_filename}")

if __name__ == "__main__":
    main()
# Out:
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001628280-22-020260/full-submission.txt...
# Saved parsed data to unknown_92ad6bcc-e975-454a-874d-e9bfc03eb8bd.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-13-000013/full-submission.txt...
# Saved parsed data to June-30,-2013.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-95-000009/full-submission.txt...
# Saved parsed data to unknown_f46dc136-e438-445e-a838-b94a07439a38.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-12-332159/full-submission.txt...
# Saved parsed data to unknown_690edabf-7137-45c4-9afe-a472bbb0f1d7.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-03-003390/full-submission.txt...
# Saved parsed data to March-31,-2003.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-08-006282/full-submission.txt...
# Saved parsed data to December-31,-2007.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-04-002772/full-submission.txt...
# Saved parsed data to March-31,-2004.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-05-003036/full-submission.txt...
# Saved parsed data to June-30,-2005.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000081033-95-000018/full-submission.txt...
# Saved parsed data to unknown_081afc36-72f5-4fc6-be2d-6c6e86e25cbb.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-95-000006/full-submission.txt...
# Saved parsed data to March-31,-1995.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-99-000037/full-submission.txt...
# Saved parsed data to September-30,-1999.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-00-000021/full-submission.txt...
# Saved parsed data to March-31,-2000.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-16-000034/full-submission.txt...
# Saved parsed data to December-31,-2015.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-17-000007/full-submission.txt...
# Saved parsed data to December-31,-2016.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-00-000010/full-submission.txt...
# Saved parsed data to March-31,-2000.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-20-000033/full-submission.txt...
# Saved parsed data to unknown_cdf50f31-5862-421d-ba1a-9272f988d16f.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000891092-02-001247/full-submission.txt...
# Saved parsed data to June-30,-2002.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-19-000009/full-submission.txt...
# Saved parsed data to unknown_3e44f321-0c1f-43e6-b5bc-c0713c4446f7.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-23-000007/full-submission.txt...
# Saved parsed data to December-31,-2022.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001628280-22-012019/full-submission.txt...
# Saved parsed data to unknown_9b1f8131-0317-4b8a-a019-679438081589.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-01-500017/full-submission.txt...
# Saved parsed data to March-31,-2001.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-15-000008/full-submission.txt...
# Saved parsed data to December-31,-2014.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-02-000074/full-submission.txt...
# Saved parsed data to June-30,-2002.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-23-000008/full-submission.txt...
# Saved parsed data to December-31,-2022.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-07-004140/full-submission.txt...
# Saved parsed data to December-31,-2006.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-18-000026/full-submission.txt...
# Saved parsed data to December-31,-2017.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-14-000010/full-submission.txt...
# Saved parsed data to March-31,-2014.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-97-000013/full-submission.txt...
# Saved parsed data to March-31,-1997.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-97-000022/full-submission.txt...
# Saved parsed data to unknown_524e1e89-1c1f-49c1-b3a5-faa3e734236b.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-08-004616/full-submission.txt...
# Saved parsed data to December-31,-2007.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-97-000015/full-submission.txt...
# Saved parsed data to June-30,-1997.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-05-001774/full-submission.txt...
# Saved parsed data to December-31,-2004.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-00-000050/full-submission.txt...
# Saved parsed data to June-30,-2000.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-20-000029/full-submission.txt...
# Saved parsed data to unknown_8ee1316d-5dae-472f-a44f-45b15362e4a0.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-98-000010/full-submission.txt...
# Saved parsed data to March-31,-1998.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-12-000003/full-submission.txt...
# Saved parsed data to unknown_1368bc04-7c18-4237-a541-5650ddd6e238.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-99-000024/full-submission.txt...
# Saved parsed data to June-30,-1999.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-16-000018/full-submission.txt...
# Saved parsed data to unknown_991d6ce6-dfc9-42c2-94d1-cb93804e01f1.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-09-003976/full-submission.txt...
# Saved parsed data to December-31,-2008.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-07-006384/full-submission.txt...
# Saved parsed data to December-31,-2006.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-20-000010/full-submission.txt...
# Saved parsed data to March-31,-2020.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-21-000012/full-submission.txt...
# Saved parsed data to unknown_c4c95eaf-75a5-4296-b9cb-2fb9a366422f.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-10-110439/full-submission.txt...
# Saved parsed data to unknown_bb2d55d4-892e-4241-bdf4-e6e126b359cc.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-13-000007/full-submission.txt...
# Saved parsed data to unknown_a18f668a-00f4-4aa5-9d8c-4c96801a7dbe.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-98-000016/full-submission.txt...
# Saved parsed data to March-31,-1998.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-17-000024/full-submission.txt...
# Saved parsed data to March-31,-2017.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-21-000034/full-submission.txt...
# Saved parsed data to June-30,-2021.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-13-000010/full-submission.txt...
# Saved parsed data to March-31,-2013.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001628280-22-027422/full-submission.txt...
# Saved parsed data to unknown_7a8ebe34-04d2-4e7d-8e31-ffd10fdf2b0b.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-09-002474/full-submission.txt...
# Saved parsed data to December-31,-2008.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-16-000038/full-submission.txt...
# Saved parsed data to December-31,-2015.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-08-002872/full-submission.txt...
# Saved parsed data to December-31,-2007.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-94-000009/full-submission.txt...
# Saved parsed data to March-31,-1994.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000081033-94-000021/full-submission.txt...
# Saved parsed data to June-30,-1994.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-03-001867/full-submission.txt...
# Saved parsed data to March-31,-2002.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001628280-24-019352/full-submission.txt...
# Saved parsed data to unknown_22eb1a45-34b4-4a02-a72e-ffb05dac2d09.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-07-008345/full-submission.txt...
# Saved parsed data to December-31,-2006.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-19-000032/full-submission.txt...
# Saved parsed data to unknown_24fa0b45-0d74-4223-86be-a3d7f85bdf82.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-15-000004/full-submission.txt...
# Saved parsed data to unknown_8ee3d396-2b2a-42eb-a558-363dacbe664a.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-96-000038/full-submission.txt...
# Saved parsed data to unknown_eb29846a-be23-438f-a722-08c323dcbf16.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-23-000002/full-submission.txt...
# Saved parsed data to December-31,-2022.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-02-000046/full-submission.txt...
# Saved parsed data to March-31,-2002.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-06-001966/full-submission.txt...
# Saved parsed data to March-31,-2006.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-12-205116/full-submission.txt...
# Saved parsed data to December-31,-2011.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001628280-24-033496/full-submission.txt...
# Saved parsed data to unknown_5a4a4e55-60ee-4d3b-8c62-1f852c23387b.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-14-000007/full-submission.txt...
# Saved parsed data to unknown_9bcab7e9-50fa-4171-bef3-dcf2713b6a7e.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-18-000007/full-submission.txt...
# Saved parsed data to March-31,-2018.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-01-500046/full-submission.txt...
# Saved parsed data to March-31,-2001.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-11-128596/full-submission.txt...
# Saved parsed data to unknown_1913fcf4-74dc-4960-9c10-534c74ae9963.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-01-500090/full-submission.txt...
# Saved parsed data to September-30,-2001.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-04-003736/full-submission.txt...
# Saved parsed data to September-30,-2004.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-18-000022/full-submission.txt...
# Saved parsed data to December-31,-2017.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-96-000024/full-submission.txt...
# Saved parsed data to unknown_0116b65f-0e04-46b0-be9b-0b1a939eb2d9.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-14-000013/full-submission.txt...
# Saved parsed data to unknown_8de1b39d-31d3-41f1-8486-d34bccad299c.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001628280-21-021195/full-submission.txt...
# Saved parsed data to unknown_ed5f4661-9f51-4f98-9010-f303d7df364a.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-15-000011/full-submission.txt...
# Saved parsed data to December-31,-2014.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-96-000015/full-submission.txt...
# Saved parsed data to unknown_ccf56f55-33e0-43e3-8f1b-0e8ca219f3c7.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-06-004492/full-submission.txt...
# Saved parsed data to December-31,-2005.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-10-172309/full-submission.txt...
# Saved parsed data to unknown_d0371097-226e-4865-bf12-dcc9305a572d.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-03-004611/full-submission.txt...
# Saved parsed data to September-30,-2003.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-19-000028/full-submission.txt...
# Saved parsed data to unknown_7d0e7499-42a0-4cd6-8299-5c4fb5b032ba.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-06-003288/full-submission.txt...
# Saved parsed data to unknown_0c1949aa-8876-411d-9838-382a35c54800.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-04-001662/full-submission.txt...
# Saved parsed data to March-31,-2004.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000950117-05-004120/full-submission.txt...
# Saved parsed data to September-30,-2005.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-10-241339/full-submission.txt...
# Saved parsed data to unknown_948929b6-7dfa-48d0-a54a-88602d938bf0.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000930413-09-005485/full-submission.txt...
# Saved parsed data to December-31,-2008.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-17-000019/full-submission.txt...
# Saved parsed data to March-31,-2017.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-98-000025/full-submission.txt...
# Saved parsed data to September-30,-1998.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-99-000011/full-submission.txt...
# Saved parsed data to March-31,-1999.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-11-290949/full-submission.txt...
# Saved parsed data to December-31,-2010.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0000788784-94-000012/full-submission.txt...
# Saved parsed data to September-30,-1994.json
# Parsing /Users/petersapountzis/Desktop/tulane/fall2024/cmps4010/Entergy-AI/parsers/sec-edgar-filings/0000788784/10-Q/0001193125-11-208082/full-submission.txt...
# Saved parsed data to unknown_56c208e4-470c-4aaa-9249-23076e3add9d.json

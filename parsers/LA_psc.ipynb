# %%
import os
import json
import re
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import NoTranscriptFound, TranscriptsDisabled

API_KEY = "AIzaSyAoa3YsfoEc3O-rygR1p-nXJ3jKW0jIUPI"
CHANNEL_ID = "UCh7aLORd63J2_xhIp9uqKHQ"

# %%
def get_all_videos(api_key, channel_id):
    """
    Fetch all video IDs and titles from a YouTube channel.
    """
    youtube = build("youtube", "v3", developerKey=api_key)
    videos = []
    next_page_token = None

    while True:
        request = youtube.search().list(
            part="id,snippet",
            channelId=channel_id,
            maxResults=50,
            pageToken=next_page_token,
            type="video"
        )
        response = request.execute()

        for item in response.get("items", []):
            if "videoId" in item["id"]:
                video_id = item["id"]["videoId"]
                title = item["snippet"]["title"]
                videos.append({"id": video_id, "title": title})

        next_page_token = response.get("nextPageToken")
        if not next_page_token:
            break

    return videos

# %%
def save_transcript(video_id, title):
    """
    Fetch and save the transcript for a video.
    """
    # Replace invalid characters in the title for file naming
    sanitized_title = "".join(c for c in title if c.isalnum() or c in " -_").strip()
    filename = f"{sanitized_title}.json"

    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        # Save the transcript to a JSON file
        with open(filename, "w") as f:
            json.dump(transcript, f, indent=4)
        print(f"Transcript saved: {filename}")
    except NoTranscriptFound:
        print(f"No transcript found for video: {title} (ID: {video_id})")
    except TranscriptsDisabled:
        print(f"Transcripts disabled for video: {title} (ID: {video_id})")
    except Exception as e:
        print(f"Error fetching transcript for video: {title} (ID: {video_id}) - {e}")

# %%
def get_channel_id(api_key, custom_handle):
    """
    Get the Channel ID for a YouTube channel using its custom handle.
    
    Args:
        api_key (str): YouTube API key.
        custom_handle (str): Custom handle of the channel (e.g., @channelname).
    
    Returns:
        str: The sanitized Channel ID.
    """
    youtube = build("youtube", "v3", developerKey=api_key)
    request = youtube.search().list(
        part="snippet",
        q=custom_handle,
        type="channel",
        maxResults=1
    )
    response = request.execute()
    if response["items"]:
        channel_id = response["items"][0]["snippet"]["channelId"]
        return channel_id.strip()  # Ensure no extra spaces or characters
    else:
        raise ValueError(f"Channel with handle {custom_handle} not found.")

# %%
def main():
    # Create a folder for transcripts
    if not os.path.exists("MISS_PSC_transcripts"):
        os.makedirs("MISS_PSC_transcripts")
    os.chdir("MISS_PSC_transcripts")

    # Step 1: Fetch all videos from the channel
    # channel_id = get_channel_id(API_KEY, '@arkansaspublicservicecommi7913')
    videos = get_all_videos(API_KEY, CHANNEL_ID)
    print(f"Found {len(videos)} videos on the channel.")

    # Step 2: Fetch and save transcripts
    for video in videos:
        save_transcript(video["id"], video["title"])

# %%
main()
# Out:
# Found 104 videos on the channel.
# Transcript saved: ENTERGY Public Workshop - August 9th 2023.json
# Transcript saved: Mississippi PSC August 3rd 2021 Public Meeting.json
# Transcript saved: Mississippi PSC August 2022 Public Meeting.json
# Transcript saved: Mississippi PSC September 2022 Public Meeting.json
# Transcript saved: Mississippi PSC February 2023 Public Meeting.json
# Transcript saved: Mississippi PSC July 8th 2021 Public Meeting.json
# Transcript saved: Mississippi PSC June 2021 Special Meeting.json
# Transcript saved: Mississippi PSC March 2021 Public Meeting.json
# Transcript saved: September 2022 Working Session 2.json
# Transcript saved: March 15 2020 Special Meeting.json
# Transcript saved: Mississippi PSC September 2023 Public Meeting.json
# Transcript saved: Mississippi PSC April 2021 Public Meeting.json
# Transcript saved: Mississippi PSC December 7th 2021 Public Meeting.json
# Transcript saved: Mississippi PSC June 8th 2021 Public Meeting.json
# Transcript saved: Mississippi PSC Live Stream - Special Meeting September 2019.json
# Transcript saved: Mississippi PSC July 11th 2023 Public Meeting.json
# Transcript saved: Mississippi PSC May 2021 Public Meeting and Hearing 2018-AD-170.json
# Transcript saved: Mississippi PSC October 2022 Public Meeting.json
# Transcript saved: Mississippi PSC Live Stream - Nov 2019 Meeting  Hearing 2019-UN-130  2018-AD-64.json
# Transcript saved: Mississippi PSC September 27 Special Meeting Hearing 2021-AD-19.json
# Transcript saved: Mississippi PSC March 2020 Meeting.json
# Transcript saved: MS Power Company Public Workshop March 31 2023.json
# Transcript saved: Mississippi PSC February 2020 Public Meeting.json
# Transcript saved: Mississippi PSC March 1st 2022 Public Meeting.json
# Transcript saved: Mississippi PSC Special Meeting - September 2020.json
# Transcript saved: Mississippi PSC September 9th 2021 Public Meeting.json
# Transcript saved: Mississippi PSC Live Stream -Hearing 2019-UA-116.json
# Transcript saved: Mississippi PSC - Great River Utility Hearing - Public Comments.json
# Transcript saved: Mississippi PSC October 14th 2021 Public Meeting.json
# Transcript saved: Mississippi PSC June 2022 Meeting with Hearing 2018-UN-205.json
# Transcript saved: April 2020 Docket.json
# Transcript saved: Mississippi PSC March 8th 2022 Special Meeting.json
# Transcript saved: Mississippi PSC Live Stream - Special Meeting October 2019.json
# Transcript saved: PSC Special Meeting September 29th 2021.json
# Transcripts disabled for video: Mississippi PSC April 5th 2022 Meeting (ID: CnvxTpDWqRc)
# Transcript saved: Mississippi PSC Public Meeting January 2023.json
# Transcript saved: Mississippi PSC November 2nd 2021 Public Meeting.json
# Transcript saved: Mississippi PSC December 7th 2021 Public Meeting Hearing.json
# Transcript saved: Mississippi PSC 2020-UA-132 Hearing.json
# Transcript saved: December 17 2020 Special Meeting.json
# Transcript saved: September 22 2020 Special Meeting.json
# Transcript saved: Mississippi PSC November 2020 Special meeting.json
# Transcript saved: Mississippi PSC Live Stream - Hearing 2019-AD-67.json
# Transcript saved: Mississippi PSC November 2022 Public Meeting.json
# Transcript saved: Mississippi PSC August 2020 Public Meeting.json
# Transcript saved: Mississippi PSC August 2023 Public Meeting.json
# Transcript saved: Mississippi PSC Live Stream - Hearing 2018-UA-204.json
# Transcript saved: Mississippi PSC November 2020 Public Meeting.json
# Transcript saved: Mississippi PSC February 2021 Regular Meeting.json
# Transcript saved: Mississippi PSC September 2020 Public Meeting.json
# Transcript saved: Mississippi PSC May 2022 Public Meeting.json
# Transcript saved: May 2020 Docket.json
# Transcripts disabled for video: Mississippi PSC - Oath of Office 2020 (ID: 7l2Fp3V5FmI)
# Transcripts disabled for video: Great River Utility - Day One Docket 2024-UN-026/2024-UN-027 (ID: 2ThYUCyjh70)
# Transcript saved: Mississippi PSC Special Meeting - Piney Woods School.json
# Transcripts disabled for video: August 2022 Special Meeting (ID: Cf0HU0PVeVk)
# Transcript saved: Mississippi PSC May 2023 Public Meeting.json
# Transcript saved: Mississippi PSC March 17th Special Meeting.json
# Transcript saved: Mississippi PSC Live Stream - Special Meeting Nov 2019.json
# Transcripts disabled for video: 2020 IRP Public Meeting (part 2) (ID: JoLWzsenIl8)
# Transcripts disabled for video: Mississippi PSC Live Stream - October 2019 Meeting (ID: mTETMakRKAU)
# Transcripts disabled for video: Mississippi PSC Live Stream - Hearing 2019-UA-60 / 2019-UA-61 (ID: W0Q1erAdUv0)
# Transcript saved: Mississippi PSC December 2024 - Public Meeting.json
# Transcript saved: December 2022 Public Meeting and Hearing 2022-UA-108 v2.json
# Transcript saved: Mississippi PSC January 2021 Public Meeting.json
# Transcript saved: Mississippi PSC March 2023 Public Meeting.json
# Transcripts disabled for video: 2020 IRP Public Meeting (part 3) (ID: PQPl3dXvlYo)
# Transcript saved: January 2022 Mississippi PSC Public Meeting.json
# Transcripts disabled for video: 2020 IRP Public Meeting (part 1) (ID: JqXIcpoq3qw)
# Transcripts disabled for video: Mississippi PSC February 8th 2021 Public Meeting (ID: wohEWD0lNBA)
# Transcript saved: Mississippi PSC July 2020 Public Meeting.json
# Transcript saved: Mississippi PSC June 2020 Public Meeting.json
# Transcript saved: Mississippi PSC Live Stream - September 2019 Meeting.json
# Transcripts disabled for video: Mississippi PSC Live Stream - August 2019 Meeting (ID: Y2PamaCg0o4)
# Transcripts disabled for video: Mississippi PSC June 2022 Special Meeting (ID: 31p_ZIZUnF8)
# Transcript saved: Mississippi PSC December 2020 Public Meeting.json
# Transcript saved: Mississippi PSC -  EDITED Hearing 2018-UA-267 2019-UN-219.json
# Transcripts disabled for video: Great River Utility - Public Comments - 2024-UN-026/2024-UN-027 (ID: koRQEwdBT6o)
# Transcript saved: Telecom for Education Conference Call.json
# Transcript saved: Mississippi PSC June 2023 Public Meeting.json
# Transcript saved: Mississippi PSC - Great River Utility - Evidentiary Hearing.json
# Transcript saved: Mississippi PSC - Great River Utility - Supplemental Hearing.json
# Transcript saved: Mississippi PSC December 2019 Public Meeting.json
# Transcript saved: Mississippi PSC October 2023 Public Meeting.json
# Transcript saved: Mississippi PSC July 2024 Public Meeting.json
# Transcript saved: Mississippi PSC January 2020 Public Meeting.json
# Transcript saved: Mississippi July 2022 Public Meeting.json
# Transcript saved: Mississippi PSC October 2020 Public Meeting.json
# Transcript saved: Mississippi PSC June 2024 Meeting.json
# Transcript saved: Mississippi PSC May 2024 Meeting.json
# Transcript saved: Mississippi PSC - August 2024 Public Meeting.json
# Transcript saved: Mississippi PSC - September 2024 Public Meeting.json
# Transcript saved: Mississippi PSC January 2024 Public Meeting.json
# Transcript saved: 2024 Solar Summit - Morning and Afternoon Sessions.json
# Transcript saved: Mississippi PSC - February 2024 Meeting.json
# Transcript saved: 2024 Nuclear Summit - Morning and Afternoon Sessions.json
# Transcript saved: Mississippi PSC Special Meeting for December 5 2023.json
# Transcript saved: Mississippi PSC December 2023 Public Meeting.json
# Transcript saved: Mississippi PSC - Work Session - Holly Springs Utility District.json
# Transcript saved: Mississippi PSC - October 2024 Public Meeting.json
# Transcript saved: Mississippi PSC March 2024 Meeting.json
# Transcript saved: Mississippi PSC - November 2024 Public Meeting.json
# Transcript saved: 2024 - Propane Summit - All Sessions.json
# Transcript saved: 2024 Water Summit - Morning and Afternoon Sessions.json

# %%
import os
import json
import re

def clean_transcript(input_file, output_file):
    """
    Cleans a transcript JSON file by removing irrelevant entries.
    - Removes lines containing '[music]' or similar tags.
    - Saves the cleaned data to a new file.
    
    Args:
        input_file (str): Path to the input JSON file.
        output_file (str): Path to the output JSON file.
    """
    # Load the JSON file
    with open(input_file, "r") as f:
        data = json.load(f)

    # Define the pattern to remove irrelevant content
    pattern = re.compile(r"\[.*?\]", re.IGNORECASE)

    # Filter out entries with irrelevant content
    cleaned_data = [
        entry for entry in data if not pattern.search(entry["text"])
    ]

    # Save the cleaned data to the output file
    with open(output_file, "w") as f:
        json.dump(cleaned_data, f, indent=4)

    print(f"Cleaned file saved: {output_file}")

def clean_all_transcripts(input_directory, output_directory):
    """
    Cleans all transcript JSON files in the specified input directory and saves
    them to the specified output directory.
    
    Args:
        input_directory (str): Path to the directory containing JSON files.
        output_directory (str): Path to the directory where cleaned files will be saved.
    """
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for filename in os.listdir(input_directory):
        if filename.endswith(".json"):
            input_file = os.path.join(input_directory, filename)
            output_file = os.path.join(output_directory, filename)
            clean_transcript(input_file, output_file)

    print(f"All transcripts cleaned and saved to {output_directory}.")

# Example usage
if __name__ == "__main__":
    input_dir = "transcripts"  # Directory containing original JSON files
    output_dir = "cleaned_transcripts"  # Directory to save cleaned JSON files
    clean_all_transcripts(input_dir, output_dir)
# Out:
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - September 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - May 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - October 2021.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - December 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - June 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - July 2021.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - June 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - December 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - November 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - September 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - March 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - June 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Advanced Nuclear Meeting.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - April 2021.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - November 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - May 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream  - January 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - November 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - September 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - March 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - August 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - November 2021.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - April 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - January 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - February 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - April 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - October 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - October 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream  - April 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - August 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - December 2021.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - July 2022.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - June 2021.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - February 2024.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - January 2023.json
# Cleaned file saved: cleaned_transcripts/Louisiana Public Service Commission Live Stream - October 2022.json
# All transcripts cleaned and saved to cleaned_transcripts.

# %%
get_channel_id(API_KEY, '@arkansaspublicservicecommi7913')
# Out:
# 'UCjCtMIrCuWBm-lXEY5fTYuw'
